# %% [markdown]
# ## 1.3.6 Data Cleaning
#
# Determine the five most common journals and the total articles for each. Next, calculate the mean, median, and standard deviation of the open-access cost per article for each journal .

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('WELLCOME/WELLCOME_APCspend2013_forThinkful.csv', 
                 low_memory=False, encoding='iso-8859-1')


df.head(10)
# Out:
#               PMID/PMCID                                     Publisher  \
# 0                    NaN                                           CUP
# 1             PMC3679557                                           ACS
# 2  23043264  PMC3506128                                            ACS
# 3    23438330 PMC3646402                                           ACS
# 4   23438216 PMC3601604                                            ACS
# 5             PMC3579457                                           ACS
# 6             PMC3709265                                           ACS
# 7   23057412 PMC3495574                                            ACS
# 8      PMCID: PMC3780468  ACS (Amercian Chemical Society) Publications
# 9      PMCID: PMC3621575  ACS (Amercian Chemical Society) Publications
#
#                     Journal title  \
# 0          Psychological Medicine
# 1               Biomacromolecules
# 2                      J Med Chem
# 3                      J Med Chem
# 4                      J Org Chem
# 5  Journal of Medicinal Chemistry
# 6    Journal of Proteome Research
# 7                       Mol Pharm
# 8            ACS Chemical Biology
# 9            ACS Chemical Biology
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
# 5  Comparative Structural and Functional Studies ...
# 6  Mapping Proteolytic Processing in the Secretom...
# 7  Quantitative silencing of EGFP reporter gene b...
# 8  A Novel Allosteric Inhibitor of the Uridine Di...
# 9  Chemical proteomic analysis reveals the drugab...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# 4                                            £685.88
# 5                                           £2392.20
# 6                                           £2367.95
# 7                                            £649.33
# 8                                           £1294.59
# 9                                           £1294.78

# %%
# Renaming last column bc the title is so long...
df.rename(index=str, columns={"COST (£) charged to Wellcome (inc VAT when charged)" : "COST"}, inplace=True)

df.head(3)
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
#
#                                        Article title      COST
# 0  Reduced parahippocampal cortical thickness in ...     £0.00
# 1  Structural characterization of a Model Gram-ne...  £2381.04
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...   £642.56

# %%
# cleaning up the Cost column - getting rid of $ , and .

df['COST'] = df['COST'].apply(lambda x: ''.join(list(filter(str.isdigit, str(x)))))

# careful, bc of decimals... need to rework this a bit

# %%
# trying to deal with the decimals

def add_dec(num):
    temp = str(num)
    temp = temp[0:-2] + '.' + temp[-2:]
    temp = float(temp)
    return temp

# and to round up to the next int there's a func - np.rint(number)

df['COST'] = df['COST'].apply(add_dec)

# rounding to the nearest integer bc floats arent reliable with currency
df['COST'] = df['COST'].apply(np.rint)

# now converting back to an int...
df['COST'] = df['COST'].astype(int)

df.head(3)
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
#
#                                        Article title  COST
# 0  Reduced parahippocampal cortical thickness in ...     0
# 1  Structural characterization of a Model Gram-ne...  2381
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...   643

# %%
df['Journal title'] = df['Journal title'].str.capitalize()
df['Journal title'] = df['Journal title'].str.strip()

mess = list(set(list(df['Journal title'])))

# using this function from https://stackoverflow.com/questions/13252333/python-check-if-all-elements-of-a-list-are-the-same-type
def homogeneous_type(seq):
    iseq = iter(seq)
    first_type = type(next(iseq))
    return first_type if all( (type(x) is first_type) for x in iseq ) else False

#print(homogeneous_type(mess[1:]))
#print(sorted(mess[1:]))

# trying to make a dictionary to correct typos in journal names
# by looking at the journal names in smaller groups
# and then adding them (not in this function)

def starting_letter(letter, outof):
    print('\n***{}***'.format(letter))
    for item in outof:
        # if its a float just get outta there, bc the only float in the list is NaN
        if type(item) != float:
            if item[0] == letter:
                print(item)

# ran the next part to clean up the biggest messes that i could easily find...

#for x in range(ord('A'),ord('Z')+1):
#    starting_letter(chr(x), mess)

# %%
correct = {'Americal journal of psychiatry': 'American journal of psychiatry',
          'Acta crystallographica section d,  biological crystallography': 'Acta crystallography d',
           'Acta crystallographica section d: biological crystallography': 'Acta crystallography d',
          'Acta crystallographica, section d': 'Acta crystallography d',
           'Antimicobial agents and chemotherapy':'Antimicrobial agents and chemotherapy',
           'Acta d': 'Acta crystallography d', 'The americal journal of human genetics':'American journal of human genetics',
           'The american journal of human genetics': 'American journal of human genetics',    
           'Angew chems int ed' : 'Angewandte chemie international edition',
           'Am j trop med hyg':'American journal of tropical medicine & hygiene',
           'Acta f': 'Acta crystallographica section f: structural biology and crystallization communications',
            'Biinformatics': 'Bioinformatics online', 
           'Bioinformatics': 'Bioinformatics online', 
           'American journal of bioethics--neuroscience': 'American journal of bioethics',
           'Am j bioeth': 'American journal of bioethics',
           'Haematologica':'Haematologica/the haematology journal',
           'Biinformatics': 'Bioinformatics online','Health & place': 'Health and place',
           'Epigentics': 'Epigenetics', 'Plosone' : 'Plos one' , 'The embo journal': 'Embo',
           'Trop med int health':'Tropical medicine and international health',
           'Journal of general virology': 'Journal of virology',
           'Angewande chemie': 'Angewandte chemie', 'Biol open': 'Biology open',
           'Bmj open': 'Biology open', 'Plos  one': 'Plos one', 'Plos 1': 'Plos one',
           'Plos': 'Plos one',
           'Biochem journal':'Journal of biological chemistry',
           'Biochimie': 'Journal of biological chemistry',
           'Biochemical journals': 'Journal of biological chemistry',
           'Biochemical journal': 'Journal of biological chemistry',
           'Biochemistry': 'Journal of biological chemistry',
           'Biological chemistry' : 'Journal of biological chemistry',
           'Biologicial chemistry': 'Journal of biological chemistry',
           'Health: an interdisciplinary journal for the social study of health, illness and medicine': 'Health'
          }

def correction(value):
    
    # first checking if its a float (that one NaN in there...) so it doesnt throw an error 
    if type(value) != float:
        
        # get rid of all 'the 's because they are inconsistently included in the titles
        if 'the ' in value:
            value = value.replace('the ',' ')
        if 'The ' in value:
            value = value.replace('The ','')
        # also drop the '.'s, inconsistency makes the titles not match
        if '.' in value:
            value = value.replace('.','')
        
        # checking in the dict for the correction
        if value in correct:
            newvalue = correct[value]
            return newvalue
        else:
            return value
    else:
        return value
        
df['Journal title'] = df['Journal title'].apply(correction)

# %%
# when the data is cleaned you should be able to just call the top 4 with .head(4) here

top5 = df.groupby('Journal title').count().sort_values(['Article title'], ascending=False).head(5)

top5
# Out:
#                                  PMID/PMCID  Publisher  Article title  COST
# Journal title
# Plos one                                201        211            211   211
# Journal of biological chemistry          69         71             71    71
# Neuroimage                               28         29             29    29
# Nucleic acids research                   25         26             26    26
# Plos genetics                            23         24             24    24

# %%
# Count of total articles per journal, just for the top 5 journals
top5['Article title']
# Out:
# Journal title
# Plos one                           211
# Journal of biological chemistry     71
# Neuroimage                          29
# Nucleic acids research              26
# Plos genetics                       24
# Name: Article title, dtype: int64

# %%
#mess2 = list(set(list(df['Journal title'])))
#for x in range(ord('A'),ord('Z')+1):
#    starting_letter(chr(x), mess)

# %%
# just double checking that the article titles are unique, so that the count above is correct

df[df['Journal title'] == 'Plos one']
# Out:
#                        PMID/PMCID                         Publisher  \
# 1282                      3517619                              PLoS
# 1283                      3498109                              PLoS
# 1284                      3515553                              PLoS
# 1285                      3522679                              PLoS
# 1286                      3485223                              PLoS
# 1287                   PMC3547059                              PLoS
# 1288                      3573029                              PLoS
# 1289                      3769269                              PLoS
# 1290                      3782430                              PLoS
# 1291                      3797097                              PLoS
# 1292                      3675909                              PLoS
# 1293                   PMC3566186                              PLOS
# 1294                   PMC3694955                              PLoS
# 1295                   PMC3729655                              PLOS
# 1296                   PMC3774797                              PLoS
# 1297                      3620162                              PLoS
# 1298                   PMC3694164                              PLOS
# 1299                      3669132                              Plos
# 1303             PMCID:PMC3711905  PLoS (Public Library of Science)
# 1304            PMCID: PMC3661540  PLoS (Public Library of Science)
# 1305             PMCID:PMC3706442  PLoS (Public Library of Science)
# 1345                     23239765         Public Library of Science
# 1346                     24147036         Public Library of Science
# 1347                     23844111         Public Library of Science
# 1348                     23527131         Public Library of Science
# 1350                          NaN         Public Library of Science
# 1351                          NaN         Public Library of Science
# 1352                          NaN         Public Library of Science
# 1353                          NaN         Public Library of Science
# 1354                          NaN         Public Library of Science
# ...                           ...                               ...
# 1562                  PMC3720940          Public Library of Science
# 1563            PMCID: PMC3748079         Public Library of Science
# 1564       PMCID:\n    PMC3579793         Public Library of Science
# 1565       PMCID:\n    PMC3732248         Public Library of Science
# 1566     PMCID:\n    PMC3767740\n         Public Library of Science
# 1567                   PMC3642175         Public Library of Science
# 1568                   PMC3594159         Public Library of Science
# 1569                   PMC3691179         Public Library of Science
# 1570            PMCID: PMC3606242         Public Library of Science
# 1571            PMCID: PMC3694102         Public Library of Science
# 1572                   PMC3475710         Public Library of Science
# 1573       PMCID:\n    PMC3636223         Public Library of Science
# 1574            PMCID: PMC3720700         Public Library of Science
# 1575         23805259 PMC3689675          Public Library of Science
# 1576           PMCID: PMC3790696          Public Library of Science
# 1577     PMCID:\n    PMC3609862\n         Public Library of Science
# 1578     PMCID:\n    PMC3647051\n         Public Library of Science
# 1579       PMCID:\n    PMC3720585         Public Library of Science
# 1580       PMCID:\n    PMC3737189         Public Library of Science
# 1581           PMCID: PMC3706538          Public Library of Science
# 1582  PMID: 23372785 PMC3556037           Public Library of Science
# 1605                   PMC3507950         Public Library of Science
# 1606                   PMC3517620         Public Library of Science
# 1607                   PMC3806823         Public Library of Science
# 1608                   PMC3661537         Public Library of Science
# 1609                   PMC3620205         Public Library of Science
# 1610                   PMC3648513         Public Library of Science
# 1611                   PMC3760871         Public Library of Science
# 1612                 PMC3777952\n         Public Library of Science
# 1613                 \nPMC3596319         Public Library of Science
#
#      Journal title                                      Article title    COST
# 1282      Plos one  HCN1 and HCN2 in Rat DRG Neurons: Levels in No...    1001
# 1283      Plos one  Fetal alcohol exposure and IQ at age 8: Eviden...    1004
# 1284      Plos one  Vitamin B-12 status during pregnancy and child...    1011
# 1285      Plos one  Validation of Dual Energy X-ray Absorptiometry...    1011
# 1286      Plos one  Associations of different phenotypes of wheezi...    1016
# 1287      Plos one  "Involvement of EphB1 receptors signalling in ...    1023
# 1288      Plos one  Reactive oxygen species modulate the barrier f...    1040
# 1289      Plos one  Chronic pravastatin but not atorvastatin treat...    1061
# 1290      Plos one  Expression of HIV-1 Vpu Leads to Loss of the V...    1061
# 1291      Plos one  Molecular phylogeny of a RING E3 ubiquitin lig...    1061
# 1292      Plos one  Anti-Müllerian hormone is not associated with ...    1080
# 1293      Plos one  A Method for Positive and Negative Selection o...     795
# 1294      Plos one  On the importance of countergradients for the ...     809
# 1295      Plos one  Telomeric repeats facilitate CENP-ACnp1 incorp...     819
# 1296      Plos one  The effect of anti-rosetting agents against ma...     855
# 1297      Plos one  Modification of the FoxP3 transcription factor...     902
# 1298      Plos one  Regulation of Trypanosoma brusei total and pol...     902
# 1299      Plos one  Localised JAK/STAT pathway activation is requi...     904
# 1303      Plos one  Automated, high accuracy classification of Par...    1062
# 1304      Plos one  Prolonged internal displacement and common men...     390
# 1305      Plos one  Genetics of callous-unemotional behavior in ch...     443
# 1345      Plos one  Understanding support for complementary and al...    1004
# 1346      Plos one  The Role of Clathrin in post-Golgi Trafficking...    1018
# 1347      Plos one  Human and animal trypanosomes in Cote d'Ivoire...    1060
# 1348      Plos one  Genetic Transformation of a Clinical (Genital ...    1067
# 1350      Plos one  In-cell NMR Characterization of the Secondary ...     850
# 1351      Plos one  Cloned defective interfering influenza virus p...    1002
# 1352      Plos one  Protein interactions in Xenopus germ plasm RNP...    1004
# 1353      Plos one  Sleep-wake sensitive mechanisms of adenosine r...    1012
# 1354      Plos one  Time to pregnancy: a computational method for ...    1021
# ...            ...                                                ...     ...
# 1562      Plos one  Population-based CD4 counts in a rural area in...  999999
# 1563      Plos one  Plant SILAC: stable-isotope labelling with ami...  999999
# 1564      Plos one  Phagocytosis Is the Main CR3-Mediated Function...  999999
# 1565      Plos one  Pneumocystis jirovecii pneumonia in tropical a...  999999
# 1566      Plos one  Phenotypic alteration of neutrophils in the bl...  999999
# 1567      Plos one  Nicotinic acid receptor GPR109A is down-regula...     900
# 1568      Plos one  Genetic Variants of MICB and PLCE1 and associa...     904
# 1569      Plos one  Genetic diversity of mycobacterium tuberculosi...     907
# 1570      Plos one  Dectin-1 regulates IL-10 production via a MSK1...     908
# 1571      Plos one  Modulation of Higher Order Chromatin Conformat...     910
# 1572      Plos one  Protein-Protein Interaction Analysis Highlight...     910
# 1573      Plos one  Inactivation of the CovR/S Virulence Regulator...     913
# 1574      Plos one  Structure of the SCAN domain of human paternal...     916
# 1575      Plos one  Structural insights into Clostridium perfringe...     919
# 1576      Plos one  Patent human infections with the whipworm, Tri...     953
# 1577      Plos one  Limitations of Augmentation Index in the Asses...     960
# 1578      Plos one  Historical Zoonoses and Other Changes in Host ...     962
# 1579      Plos one  lung macrophages contribute to house dust mite...     962
# 1580      Plos one  Increasing adolescent HIV prevalence in easter...     962
# 1581      Plos one  Household transmission of rotavirus in a commu...     987
# 1582      Plos one  Stimulation of inositol 1,4,5-triphosphate (IP...     996
# 1605      Plos one  Systematic review of TST responses in people l...     843
# 1606      Plos one  Impact of anthelminthic treatment in pregnancy...     843
# 1607      Plos one  Methods of identifying neisseria manigitidis c...     851
# 1608      Plos one  Rates of switching antiretroviral drugs in a p...     871
# 1609      Plos one  Association between milk and milk product cons...     879
# 1610      Plos one  Alcohol-related dysfunction in working-age men...     879
# 1611      Plos one  Acute maternal infection and risk of pre-eclam...     885
# 1612      Plos one  Retinal Nerve Fibre Layer Thickness and Contra...  999999
# 1613      Plos one  Effect of genital herpes on cervicovaginal HIV...     904
#
# [211 rows x 5 columns]

# %% [markdown]
# ** Next, calculate the mean, median, and standard deviation of the open-access cost per article for each journal .

# %%
top5_titles = top5.index.tolist()

def printout(title):
    # make a table to calc from
    table = df.loc[lambda df: df['Journal title'] == title, :'COST']
    # just printing the name to minimize confusion
    print('Journal: {}'.format(title))
    print('Mean cost: {}'.format(table['COST'].mean()))
    print('Median cost: {}'.format(np.median(table['COST'])))
    print('Standard deviation of cost: {}\n'.format(np.std(table['COST'])))
    return

for journal in top5_titles:
    printout(journal)
# Out:
# Journal: Plos one
# Mean cost: 39724.71563981043
# Median cost: 902.0
# Standard deviation of cost: 191084.60441929978
#
# Journal: Journal of biological chemistry
# Mean cost: 15575.87323943662
# Median cost: 1557.0
# Standard deviation of cost: 117661.85924293843
#
# Journal: Neuroimage
# Mean cost: 2215.137931034483
# Median cost: 2326.0
# Standard deviation of cost: 261.9043947884657
#
# Journal: Nucleic acids research
# Mean cost: 1149.0
# Median cost: 852.0
# Standard deviation of cost: 434.33884326552095
#
# Journal: Plos genetics
# Mean cost: 84839.375
# Median cost: 1718.5
# Standard deviation of cost: 275931.04639124556
